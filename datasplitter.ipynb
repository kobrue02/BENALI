# %%
import pandas as pd

# %%
from sklearn.model_selection import train_test_split

def split_data(df):
    # First split: train vs test
    X_train, X_test, y_train, y_test = train_test_split(
        df['sentence'],
        df['l1'],
        test_size=0.2,
        random_state=42,
        stratify=df['l1']
    )
    
    # Second split: train vs validation  
    X_train, X_val, y_train, y_val = train_test_split(
        X_train,
        y_train,
        test_size=0.25,  # 0.25 * 0.8 = 0.2 of total
        random_state=42,
        stratify=y_train
    )
    
    train_data = pd.DataFrame({'sentence': X_train, 'l1': y_train}).dropna()
    val_data = pd.DataFrame({'sentence': X_val, 'l1': y_val}).dropna()
    test_data = pd.DataFrame({'sentence': X_test, 'l1': y_test}).dropna()
    
    train_data.to_csv("nli_train.csv", index=False)
    val_data.to_csv("nli_val.csv", index=False)
    test_data.to_csv("nli_test.csv", index=False)
    
    return train_data, val_data, test_data

# %%
path = "dataset_raw.csv"
df = pd.read_csv(path).dropna()
min_samples = 3
class_counts = df['l1'].value_counts()
valid_classes = class_counts[class_counts >= min_samples].index
df = df[df['l1'].isin(valid_classes)]
df.head()
# Out:
#                                             sentence          l1       l2  \
# 0  If you're so concerned with human rights viola...  Kazakhstan  English
# 1            Not really, I mean 75 years have passed  Kazakhstan  English
# 2  On the contrary, I've heard a lot of positive ...  Kazakhstan  English
# 3    Isn't the company Voss owned by the Chinese now  Kazakhstan  English
# 4  Lol, you just opened a historical loophole in ...  Kazakhstan  English
#
#                                               source  word_count
# 0  https://github.com/masalha-alaa/native-languag...          19
# 1  https://github.com/masalha-alaa/native-languag...           8
# 2  https://github.com/masalha-alaa/native-languag...          40
# 3  https://github.com/masalha-alaa/native-languag...           9
# 4  https://github.com/masalha-alaa/native-languag...          11

# %%
split_data(df)
# Out:
# (                                                 sentence  \
#  266284  In the UK, tree cover was down to about 10% by...
#  604748  S-bahn trains travel many kilometers outside t...
#  784223                    mlajša  hčerka  je  moja mama .
#  531837  That battle and oppresion of Chinese caused Tu...
#  654847             Taky černu taškua polibek od manželky.
#  ...                                                   ...
#  574970  Some of their aims was to replan housing to fo...
#  96474           "Predictions only at the end of the game"
#  762226    Nisam  imel  takvo  situacijo  v restavraciji .
#  193683  We call it “fön” which is short for ”hårfön” (...
#  743410                 Prihaje  iz  mesto [XKrajX],  iz .
#
#                              l1
#  266284                 Croatia
#  604748                   Italy
#  784223                  Poland
#  531837                  Turkey
#  654847                  Russia
#  ...                        ...
#  574970                 Finland
#  96474                 Portugal
#  762226  Bosnia and Herzegovina
#  193683                  Sweden
#  743410         North Macedonia
#
#  [485982 rows x 2 columns],
#                                                   sentence               l1
#  242677  What that essentially means is that the region...          Denmark
#  767336                   Ni  mi  všeč  gledati komedije .  North Macedonia
#  118307                  "Weltschmertz" is a fine word too           Norway
#  314392                Both towns are as flat as I am, too           Poland
#  1096    You have to click on the edit flair button on ...           France
#  ...                                                   ...              ...
#  358105                             Downvote me all I want           Canada
#  527570  Ugunsgrēks = Fire-sin (fire as a tragedy, e.g....           Latvia
#  460921  The land people go to if they want a cheaper i...          Austria
#  66545   Other than what you mentioned, GDP also doesn'...      Netherlands
#  551781  However, I don't know about any OLAP (or bette...          Czechia
#
#  [161994 rows x 2 columns],
#                                                   sentence        l1
#  78020   It would be moree accurate to say Athens (3 mi...    Greece
#  802034  #编号：540\n#篇名：兄弟射雁\n#字数／字符数：411/411\n#类型：习作\n#姓...   Vietnam
#  99729   Not that they are poor, they just don't give m...  Portugal
#  107733     Red in the corners with white surrounding them    Norway
#  186569                >Wenn es stets zu Schutz und Trutze   Germany
#  ...                                                   ...       ...
#  702306  Danes  je  veliko  različnih subkultur, panker...    Serbia
#  460081  I’d move to Bavaria and have the water right t...   Austria
#  108165  People have panic bought masks and anti-bacter...    Norway
#  170482                 even 6 weeks would be seen as much   Germany
#  674146                Můj tatínek je velmi konzervativní.     Japan
#
#  [161994 rows x 2 columns])
